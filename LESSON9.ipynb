# %%
# Linear Regression
import os 
import pandas as pd

# %%
os.chdir(r'C:\Users\Admin\Pytraining')

# %%
df = pd.read_csv('train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Age'] = df['Age'].fillna(method = 'ffill')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
na_age = df['Age'].isna()
c = na_age[na_age==True].count()

# %%
c
# Out:
# 177

# %%
na_cabin = df['Cabin'].isna()
c = na_cabin[na_cabin==True].count()
print(c)
# Out:
# 687

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
import numpy as np
pivot_embark = pd.pivot_table(df,index= 'Embarked',values ='Survived',aggfunc =np.mean)
pivot_embark
# Out:
#           Survived
# Embarked
# C         0.553571
# Q         0.389610
# S         0.336957

# %%
# https://pandas.pydata.org/docs/reference/api/pandas.get_dummies.html
sex = pd.get_dummies(df,columns=['Sex'])
sex
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                             Allen, Mr. William Henry  35.0      0      0
# ..                                                 ...   ...    ...    ...
# ...

# %%
embarked_df = pd.get_dummies(sex,columns=['Embarked'])
embarked_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                             Allen, Mr. William Henry  35.0      0      0
# ..                                                 ...   ...    ...    ...
# ...

# %%
embarked_df.drop(['PassengerId','Name','Cabin','Ticket'], axis = 1,inplace =True)

# %%
embarked_df
# Out:
#      Survived  Pclass   Age  SibSp  Parch     Fare  Sex_female  Sex_male  \
# 0           0       3  22.0      1      0   7.2500           0         1
# 1           1       1  38.0      1      0  71.2833           1         0
# 2           1       3  26.0      0      0   7.9250           1         0
# 3           1       1  35.0      1      0  53.1000           1         0
# 4           0       3  35.0      0      0   8.0500           0         1
# ..        ...     ...   ...    ...    ...      ...         ...       ...
# 886         0       2  27.0      0      0  13.0000           0         1
# 887         1       1  19.0      0      0  30.0000           1         0
# 888         0       3  19.0      1      2  23.4500           1         0
# 889         1       1  26.0      0      0  30.0000           0         1
# 890         0       3  32.0      0      0   7.7500           0         1
#
#      Embarked_C  Embarked_Q  Embarked_S
# 0             0           0           1
# ...

# %%
# Divide two field ( train field and test field)
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# %%
pclass = pd.get_dummies(embarked_df,columns =['Pclass'])
pclass
# Out:
#      Survived   Age  SibSp  Parch     Fare  Sex_female  Sex_male  Embarked_C  \
# 0           0  22.0      1      0   7.2500           0         1           0
# 1           1  38.0      1      0  71.2833           1         0           1
# 2           1  26.0      0      0   7.9250           1         0           0
# 3           1  35.0      1      0  53.1000           1         0           0
# 4           0  35.0      0      0   8.0500           0         1           0
# ..        ...   ...    ...    ...      ...         ...       ...         ...
# 886         0  27.0      0      0  13.0000           0         1           0
# 887         1  19.0      0      0  30.0000           1         0           0
# 888         0  19.0      1      2  23.4500           1         0           0
# 889         1  26.0      0      0  30.0000           0         1           1
# 890         0  32.0      0      0   7.7500           0         1           0
#
# ...

# %%
y = pclass['Survived']
X = pclass.drop('Survived', axis = 1)

# %%
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html
logmodel = LogisticRegression()

# %%
# random_state : số lần mà sóc bao nhiêu lần trc khi nó chia data ra, sóc ngẫu nhiên
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state =101)

# %%
logmodel.fit(X_train, y_train)
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
predictions = logmodel.predict(X_test)

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.88      0.82       154
#            1       0.80      0.65      0.71       114
#
#     accuracy                           0.78       268
#    macro avg       0.78      0.76      0.77       268
# weighted avg       0.78      0.78      0.78       268

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test,predictions))
# Out:
# [[135  19]
#  [ 40  74]]

# %%
# confustion matrix 
# False positive =FP : sai 1 cách tích cực ( sai nhưng an toàn)
# False negative = FN 
# True positive = TP ( qtrong nhất)
# True negative = TN 
# precision = TP/(TP+TN)
# Recall = TP/(TP+FN) ( nhìn vô đây để cải thiện model ) : từng tthop nhìn vô để predict và cải thiện model
# F1 - score (tbinh cộng của precison và Recall)

# %%
# AUTOMATIC FORM BY PYTHON
import os
os.chdir(r'C:\Users\Admin\Pytraining')

# %%
from mailmerge import MailMerge
doc = MailMerge('templates.docx')

# %%
doc.get_merge_fields()
# Out:
# {'Gender', 'NRIC', 'Name'}

# %%
doc.merge(
Gender ='Female',
NRIC = '0000012345',
Name ='Nguyen Van A'
)
doc.write('ND_output.docx')

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r"C:\Users\Admin\Pytraining\signs_up.xlsx", sheet_name ='Sheet1')

# %%
df
# Out:
#    ID NAME GENDER     CMND
# 0   1    a      m  1234589
# 1   2    b      f    12345
# 2   3    c      m    85955

# %%
for i in range(len(df)):
    doc =MailMerge('templates.docx')
    doc.merge(
        Gender = df['GENDER'][i],
        Name = df['NAME'][i],
        CMND = str(df['CMND'][i])
    )
    doc.write('{}_output.docx'.format(df['ID'][i]))
